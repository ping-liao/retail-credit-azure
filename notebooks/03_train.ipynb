# %%
# %pip install xgboost lightgbm scikit-learn pyarrow azure-identity azure-storage-file-datalake -q
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import os, subprocess
repo_path = "/home/azureuser/cloudfiles/code/Users/pliao/retail-credit-azure"
result = subprocess.run(["git", "pull"], cwd=repo_path, capture_output=True, text=True)
print(result.stdout or "Up to date")
print(result.stderr)
# Out:
# Already up to date.

# %%
import subprocess, sys
result = subprocess.run(
    [sys.executable, "src/train.py"],
    cwd=repo_path,
    capture_output=True,
    text=True
)
print(result.stdout)
print(result.stderr)
# Out:
# Reading silver parquet...
#   1,344,080 rows loaded
#   Train: 1,012,780  Test: 253,196
#   Default rate — train: 19.53%  test: 19.53%
#
# Training logistic_regression...
#   AUC-ROC: 0.7065  F1: 0.4196  Accuracy: 0.6601
# 🏃 View run logistic_regression at: https://centralus.api.azureml.ms/mlflow/v2.0/subscriptions/1872aeb8-e08f-4c08-8309-3b8464d9258e/resourceGroups/rg-retail-credit/providers/Microsoft.MachineLearningServices/workspaces/aml-retail-credit-rc01/#/experiments/867c8ddc-8b3f-413b-ba42-29ff17dbd04a/runs/446da641-c8ad-4ce8-974c-202a264d8a97
# 🧪 View experiment at: https://centralus.api.azureml.ms/mlflow/v2.0/subscriptions/1872aeb8-e08f-4c08-8309-3b8464d9258e/resourceGroups/rg-retail-credit/providers/Microsoft.MachineLearningServices/workspaces/aml-retail-credit-rc01/#/experiments/867c8ddc-8b3f-413b-ba42-29ff17dbd04a
#
# Training xgboost...
#   AUC-ROC: 0.7174  F1: 0.4282  Accuracy: 0.6465
# 🏃 View run xgboost at: https://centralus.api.azureml.ms/mlflow/v2.0/subscriptions/1872aeb8-e08f-4c08-8309-3b8464d9258e/resourceGroups/rg-retail-credit/providers/Microsoft.MachineLearningServices/workspaces/aml-retail-credit-rc01/#/experiments/867c8ddc-8b3f-413b-ba42-29ff17dbd04a/runs/5de25b73-f306-4de7-a4e7-e454da8f97f6
# 🧪 View experiment at: https://centralus.api.azureml.ms/mlflow/v2.0/subscriptions/1872aeb8-e08f-4c08-8309-3b8464d9258e/resourceGroups/rg-retail-credit/providers/Microsoft.MachineLearningServices/workspaces/aml-retail-credit-rc01/#/experiments/867c8ddc-8b3f-413b-ba42-29ff17dbd04a
#
# Training lightgbm...
#   AUC-ROC: 0.7172  F1: 0.427  Accuracy: 0.6444
# 🏃 View run lightgbm at: https://centralus.api.azureml.ms/mlflow/v2.0/subscriptions/1872aeb8-e08f-4c08-8309-3b8464d9258e/resourceGroups/rg-retail-credit/providers/Microsoft.MachineLearningServices/workspaces/aml-retail-credit-rc01/#/experiments/867c8ddc-8b3f-413b-ba42-29ff17dbd04a/runs/a5687297-f6c1-42a7-aa95-288ce6846ee4
# 🧪 View experiment at: https://centralus.api.azureml.ms/mlflow/v2.0/subscriptions/1872aeb8-e08f-4c08-8309-3b8464d9258e/resourceGroups/rg-retail-credit/providers/Microsoft.MachineLearningServices/workspaces/aml-retail-credit-rc01/#/experiments/867c8ddc-8b3f-413b-ba42-29ff17dbd04a
#
# Winner: xgboost
# {
#   "auc_roc": 0.7174,
#   "f1": 0.4282,
#   "accuracy": 0.6465,
#   "precision": 0.313,
#   "recall": 0.6776
# }
#               precision    recall  f1-score   support
#
#   Fully Paid       0.89      0.64      0.74    203744
#  Charged Off       0.31      0.68      0.43     49452
#
#     accuracy                           0.65    253196
#    macro avg       0.60      0.66      0.59    253196
# weighted avg       0.78      0.65      0.68    253196
#
#   Winner model saved to gold/lending-club/model.joblib
# Writing scored predictions to gold/lending-club/scored_predictions.parquet...
#   Done — 253,196 rows written
#
# Training complete.
#
# /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages/xgboost/training.py:200: UserWarning: [19:35:25] WARNING: /__w/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)

# %%
from azure.storage.filedatalake import DataLakeServiceClient
from azure.identity import DefaultAzureCredential

service_client = DataLakeServiceClient(
    account_url="https://stretailcreditrc01.dfs.core.windows.net",
    credential=DefaultAzureCredential()
)
paths = service_client.get_file_system_client("gold").get_paths("lending-club")
for p in paths:
    print(p.name, f"  {round(p.content_length/1024/1024, 1)} MB")
# Out:
# ---------------------------------------------------------------------------
# ResourceNotFoundError                     Traceback (most recent call last)
# Cell In[3], line 9
#       4 service_client = DataLakeServiceClient(
#       5     account_url="https://stretailcreditrc01.dfs.core.windows.net",
#       6     credential=DefaultAzureCredential()
#       7 )
#       8 paths = service_client.get_file_system_client("gold").get_paths("lending-club")
# ----> 9 for p in paths:
#      10     print(p.name, f"  {round(p.content_length/1024/1024, 1)} MB")
#
# File /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages/azure/core/paging.py:136, in ItemPaged.__next__(self)
#     134 if self._page_iterator is None:
#     135     self._page_iterator = itertools.chain.from_iterable(self.by_page())
# --> 136 return next(self._page_iterator)
#
# File /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages/azure/core/paging.py:82, in PageIterator.__next__(self)
#      80     raise StopIteration("End of paging")
#      81 try:
# ---> 82     self._response = self._get_next(self.continuation_token)
#      83 except AzureError as error:
#      84     if not error.continuation_token:
#
# File /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages/azure/storage/filedatalake/_list_paths_helper.py:191, in PathPropertiesPaged._get_next_cb(self, continuation_token)
#     182     return self._command(
#     183         self.recursive,
#     184         continuation=continuation_token or None,
#    (...)
#     188         cls=return_headers_and_deserialized_path_list
#     189     )
#     190 except HttpResponseError as error:
# --> 191     process_storage_error(error)
#
# File /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages/azure/storage/filedatalake/_deserialize.py:259, in process_storage_error(storage_error)
#     255 error.args = (error.message,)
#     257 try:
#     258     # `from None` prevents us from double printing the exception (suppresses generated layer error context)
# --> 259     exec("raise error from None")   # pylint: disable=exec-used # nosec
#     260 except SyntaxError as exc:
#     261     raise error from exc
#
# File <string>:1
#
# File /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages/azure/storage/filedatalake/_list_paths_helper.py:182, in PathPropertiesPaged._get_next_cb(self, continuation_token)
#     180 def _get_next_cb(self, continuation_token):
#     181     try:
# --> 182         return self._command(
#     183             self.recursive,
#     184             continuation=continuation_token or None,
#     185             path=self.path,
#     186             max_results=self.results_per_page,
#     187             upn=self.upn,
#     188             cls=return_headers_and_deserialized_path_list
#     189         )
#     190     except HttpResponseError as error:
#     191         process_storage_error(error)
#
# File /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages/azure/core/tracing/decorator.py:119, in distributed_trace.<locals>.decorator.<locals>.wrapper_use_tracer(*args, **kwargs)
#     117 # If tracing is disabled globally and user didn't explicitly enable it, don't trace.
#     118 if user_enabled is False or (not tracing_enabled and user_enabled is None):
# --> 119     return func(*args, **kwargs)
#     121 # Merge span is parameter is set, but only if no explicit parent are passed
#     122 if merge_span and not passed_in_parent:
#
# File /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages/azure/storage/filedatalake/_generated/operations/_file_system_operations.py:748, in FileSystemOperations.list_paths(self, recursive, request_id_parameter, timeout, continuation, path, max_results, upn, **kwargs)
#     745 response = pipeline_response.http_response
#     747 if response.status_code not in [200]:
# --> 748     map_error(status_code=response.status_code, response=response, error_map=error_map)
#     749     error = self._deserialize.failsafe_deserialize(_models.StorageError, pipeline_response)
#     750     raise HttpResponseError(response=response, model=error)
#
# File /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages/azure/core/exceptions.py:163, in map_error(status_code, response, error_map)
#     161     return
#     162 error = error_type(response=response)
# --> 163 raise error
#
# ResourceNotFoundError: The specified path does not exist.
# RequestId:b4c4a8e7-e01f-006b-28d7-e35ae0000000
# Time:2026-05-14T19:26:10.5737620Z
# ErrorCode:PathNotFound
